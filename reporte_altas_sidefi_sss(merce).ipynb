# %%
import pandas as pd
import numpy as np
import xlwt
import xlrd
from tkinter import filedialog
import tkinter as tk
import customtkinter as ctk
from customtkinter import filedialog
import funciones
import re
import openpyxl

# %% [markdown]
# ### SUBIR PADRON SSS

# %%
archivo = None
while True:
    archivo = funciones.seleccionar_archivo()
    print(archivo)
    if archivo:
        ruta_archivo =  archivo.name # es para obtner la direccion correcta del archivo con extencion.
        columnas = [    "Código de Obra Social",
                        "CUIT del empleador",
                        "CUIL del Titular",
                        "Código de Parentesco",
                        "Cuil",
                        "Tipo Documento",
                        "Número Documento",
                        "Apellido y Nombre",
                        "Sexo",
                        "Estado Civil",
                        "Fecha de Nacimiento",
                        "Nacionalidad",
                        "Calle",
                        "Número de puerta",
                        "Piso",
                        "Departamento",
                        "Localidad",
                        "Código Postal",
                        "Provincia",
                        "Tipo de Domicilio",
                        "Teléfono",
                        "Situación revista",
                        "Incapacidad",
                        "Tipo de beneficiario titular",
                        "Fecha de alta en la Obra Social",
                        "Fecha de cierre de la presentación",
                        "Valida CUIL",
                        "CUIL informado por la OS",
                        "Tipo beneficiario informado en la DDJJ (Declaración Jurada del empleador)",
                        "CUIT empleador informante en la DDJJ",
                        "Obra Social declarada en la DDJJ",
                        "Ultimo período declarado por el empleador en la DDJJ",
                        "Obra Social elegida (en caso de opción)",
                        "Período desde de vigencia de la opción"
                        ]
        try:
            padron_sss = pd.read_csv(ruta_archivo, sep='|', names=columnas)

            print (padron_sss)
            break
        except UnicodeDecodeError:
            print("Error de decodificación de caracteres. Intenta con otra codificación o archivo.")
            continue
    else:
        print("Archivo incorrecto. Por favor, vuelva a cargarlo.")
# Out:
# <_io.TextIOWrapper name='C:/Users/zickd/Downloads/127406-202308-PC.txt' mode='r' encoding='cp1252'>
#        Código de Obra Social  CUIT del empleador  CUIL del Titular  \
# 0                     127406         20120810805       27264313061
# 1                     127406         30714444162       20214552478
# 2                     127406         30714444162       20214552478
# 3                     127406         30714444162       20214552478
# 4                     127406         30570955388       20246881422
# ...                      ...                 ...               ...
# 15374                 127406         30535218044       27256232761
# 15375                 127406         30516283781       20275000303
# 15376                 127406         27922688082       27942342174
# 15377                 127406         30521422390       20339323055
# 15378                 127406         30712103317       27356670723
#
#        Código de Parentesco         Cuil Tipo Documento  Número Documento  \
# 0                         3  23501396419             DU          50139641
# 1                         0  20214552478             DU          21455247
# 2                         3  20446262719             DU          44626271
# 3                         3  27489874291             DU          48987429
# 4                         3  20494359325             DU          49435932
# ...                     ...          ...            ...               ...
# 15374                     0  27256232761             DU          25623276
# 15375                     0  20275000303             DU          27500030
# 15376                     0  27942342174             DU          94234217
# 15377                     0  20339323055             DU          33932305
# 15378                     0  27356670723             DU          35667072
#
#                     Apellido y Nombre Sexo  Estado Civil  ...  \
# 0      GUZMAN Martin                     M             1  ...
# 1      VERGELIN ALBERTO MIGUEL           M             2  ...
# 2      VERGELIN Santino Luca             M             1  ...
# 3      VERGELIN Mia                      F             1  ...
# 4      CHOQUE S. Hector Santiago         M             1  ...
# ...                               ...  ...           ...  ...
# 15374  SMITH NANCY FERNANDA              F             0  ...
# 15375  CASTILLO JOSE LUIS                M             0  ...
# 15376  BRUNAGA VERA NANCY EDIT           F             0  ...
# 15377  FARUT DANIEL ALEJANDRO            M             0  ...
# 15378  FLORES VANESA ELIZABETH           F             0  ...
#
#        Fecha de alta en la Obra Social  Fecha de cierre de la presentación  \
# 0                             26012012                            31012012
# 1                             22022022                            28022023
# 2                             25062008                            31072009
# 3                              6022009                            31072009
# 4                              2062009                            30062009
# ...                                ...                                 ...
# 15374                          1082023                            31082023
# 15375                          1082023                            31082023
# 15376                          1082023                            31082023
# 15377                          1082023                            31082023
# 15378                          1082023                            31082023
#
#       Valida CUIL CUIL informado por la OS  \
# 0             100
# 1             100
# 2             100
# 3             100
# 4             100
# ...           ...                      ...
# 15374         100
# 15375         100
# 15376         100
# 15377         100
# 15378         100
#
#       Tipo beneficiario informado en la DDJJ (Declaración Jurada del empleador)  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 15374
# 15375
# 15376
# 15377
# 15378
#
#       CUIT empleador informante en la DDJJ Obra Social declarada en la DDJJ  \
# 0                              20120810805                           127406
# 1                              30714444162                           127406
# 2                              30714444162                           127406
# 3                              30714444162                           127406
# 4                              30570955388                           127406
# ...                                    ...                              ...
# 15374                          30535218044                           127406
# 15375                          30516283781                           127406
# 15376                          27922688082                           127406
# 15377                          30521422390                           127406
# 15378                          30712103317                           127406
#
#       Ultimo período declarado por el empleador en la DDJJ  \
# 0                                                 202308
# 1                                                 202308
# 2                                                 202308
# 3                                                 202308
# 4                                                 202308
# ...                                                  ...
# 15374                                             202308
# 15375                                             202308
# 15376                                             202308
# 15377                                             202308
# 15378                                             202308
#
#        Obra Social elegida (en caso de opción)  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ...                                        ...
# 15374                                        0
# 15375                                        0
# 15376                                        0
# 15377                                        0
# 15378                                        0
#
#        Período desde de vigencia de la opción
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ...                                       ...
# 15374                                       0
# 15375                                       0
# 15376                                       0
# 15377                                       0
# 15378                                       0
#
# [15379 rows x 34 columns]

# %% [markdown]
# ## cargar padron de sidefi

# %%
archivo = None
while True:
    archivo = funciones.seleccionar_archivo()
    print(archivo)
    if archivo:
        ruta_archivo = archivo.name
        try:
            #padron = pd.read_excel(ruta_archivo)
            padron = pd.read_csv(archivo, sep=";", encoding="ISO-8859-1")
            print(padron)
            break
        except UnicodeDecodeError:
            print("Error de decodificación de caracteres. Intenta con otra codificación o archivo.")
            continue
    else:
        print("Archivo incorrecto. Por favor, vuelva a cargarlo.")
# Out:
# <_io.TextIOWrapper name='C:/Users/zickd/Downloads/15-11-2023_padron_total_sidefi - copia.csv' mode='r' encoding='cp1252'>
#        Nro. OS          Plan del Afiliado Opcion  Nro. Grupo Familiar  \
# 0            1                   Afiliado     NO             30851327
# 1            7  Monotributista social EPV     SI             26407599
# 2            7  Monotributista social EPV     SI             26407599
# 3            7  Monotributista social EPV     SI             26407599
# 4            1                   Afiliado     SI             30694069
# ...        ...                        ...    ...                  ...
# 70093        1                   Afiliado     NO             30960682
# 70094        1                   Afiliado     NO             95019056
# 70095        1                   Afiliado     NO             28437197
# 70096        1                   Afiliado     SI             36602782
# 70097        7  Monotributista social EPV     SI             32749818
#
#          Nro. Afiliado Parentesco con el TITULAR Apellido Afiliado  \
# 0      080-30851327-00                   TITULAR             ABACA
# 1      020-26407599-00                   TITULAR              ABAD
# 2      020-26407599-02                    Hijo/a             TEVEZ
# 3      020-26407599-03                    Hijo/a             TEVEZ
# 4      010-30694069-00                   TITULAR             ABADI
# ...                ...                       ...               ...
# 70093  020-30960682-00                   TITULAR           ZUYGART
# 70094  030-95019056-00                   TITULAR          ZUZUNAGA
# 70095  010-28437197-00                   TITULAR            ZWANIK
# 70096  010-36602782-00                   TITULAR         ZWIERCZYK
# 70097  010-32749818-00                   TITULAR              SOSA
#
#            Nombre Afiliado                Tipo Documento  Nro. Documento  ...  \
# 0                  MARCELO  Documento Nacional Identidad        30851327  ...
# 1                   VANESA  Documento Nacional Identidad        26407599  ...
# 2                    MATEO  Documento Nacional Identidad        47279801  ...
# 3      MARTIN HERNAN ALEJA  Documento Nacional Identidad        44547669  ...
# 4               PEDRO RAUL  Documento Nacional Identidad        30694069  ...
# ...                    ...                           ...             ...  ...
# 70093        CLAUDIO DARIO  Documento Nacional Identidad        30960682  ...
# 70094         JOSE ENRIQUE  Documento Nacional Identidad        95019056  ...
# 70095         JACOBO CESAR  Documento Nacional Identidad        28437197  ...
# 70096        HECTOR DAMIAN  Documento Nacional Identidad        36602782  ...
# 70097        LUIS GERONIMO  Documento Nacional Identidad        32749818  ...
#
#       Piso Departamento Barrio         Localidad     Provincia Codigo Postal  \
# 0      0.0          NaN    NaN   CAPITAL FEDERAL  BUENOS AIRES           NaN
# 1      NaN          NaN    NaN     VICENTE LOPEZ  BUENOS AIRES          1638
# 2      NaN          NaN    NaN     VICENTE LOPEZ  BUENOS AIRES          1638
# 3      NaN          NaN    NaN     VICENTE LOPEZ  BUENOS AIRES          1638
# 4      NaN          NaN    NaN             MERLO  BUENOS AIRES          1722
# ...    ...          ...    ...               ...           ...           ...
# 70093  0.0          NaN    NaN             PILAR  BUENOS AIRES          1629
# 70094  NaN          NaN    NaN             MORON  BUENOS AIRES             .
# 70095  1.0            4    NaN   CAPITAL FEDERAL  BUENOS AIRES          1408
# 70096  NaN          NaN    NaN  FLORENCIO VARELA  BUENOS AIRES          1888
# 70097  NaN          NaN    NaN    FRAILE PINTADO         JUJUY          4506
#
#            Telefono        Celular                    Email Unnamed: 34
# 0                 0                                     NaN         NaN
# 1                       1135614959                      NaN         NaN
# 2               NaN            NaN                      NaN         NaN
# 3               NaN            NaN                      NaN         NaN
# 4                     11 5937-8276  pedro_abadi@hotmail.com         NaN
# ...             ...            ...                      ...         ...
# 70093             0                                     NaN         NaN
# 70094                                                   NaN         NaN
# 70095     2071-8634                                     NaN         NaN
# 70096  11 4221-4317  11 1552280736                      NaN         NaN
# 70097                   3886595110                      NaN         NaN
#
# [70098 rows x 35 columns]
# C:\Users\zickd\AppData\Local\Temp\ipykernel_18228\1184571690.py:9: DtypeWarning: Columns (10,20,24,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   padron = pd.read_csv(archivo, sep=";", encoding="ISO-8859-1")

# %% [markdown]
# ## Cruzar los datos

# %%
cruce_sidefi = pd.merge(padron, padron_sss, left_on='Nro. Documento', right_on='Número Documento', how='right', indicator=True)
cruce_sidefi
save_path = filedialog.askdirectory()
cruce_sidefi.to_excel(save_path + '\cruce_sss.xlsx', engine='openpyxl' ,index = False )

# %%
cruce_sidefi['Dependencia'].fillna('sin_sede', inplace=True)

# %%
groups = cruce_sidefi.groupby('Dependencia') # Agrupar el dataframe por la columna convenio
dfs = [] # Crear una lista vacía para almacenar los dataframes separados
for name, group in groups: # Iterar sobre los grupos y añadir cada dataframe a la lista
    dfs.append(group)
    print(dfs) # Imprimir la lista de dataframes

save_path = filedialog.askdirectory()
cruce_sidefi.to_excel(save_path + '\devoluciones2_septiembre2023.xlsx', engine='openpyxl' ,index = False )

### guardarlos con los nombres correspondientes
for df in dfs: # Iterar sobre la lista de dataframes
    sede = df['Dependencia'].iloc[0] # Obtener el nombre del convenio del primer elemento del grupo
    filename = save_path + '/' + sede + '.xlsx' # Crear el nombre del archivo con la ruta de la carpeta y el nombre del convenio
    df.to_excel(filename, index=False) # Guardar el dataframe en el archivo excel sin el índice
    print(f"Se ha guardado el archivo {filename}") # Imprimir un mensaje de confirmación
